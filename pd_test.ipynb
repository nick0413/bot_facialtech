# %%
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt
# from datetime import datetime

# %%
def moving_average(data, window_size):
    # Create a window of ones
    window = np.ones(window_size) / window_size

    # Use the convolve function to calculate the moving average
    ma = np.convolve(data, window, mode='valid')

    return ma

# %%
df=pd.read_csv("Datos.csv",dtype='str')
df[df.columns[1:]] = df[df.columns[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).apply(lambda x: x.str.replace('.','')).astype(np.float64)
fechas=df['fecha'].to_frame()
x=df.drop(columns=["fecha"])
datos=x.to_numpy()
datos.shape
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3196\813817882.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[df.columns[1:]] = df[df.columns[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).apply(lambda x: x.str.replace('.','')).astype(np.float64)
# (516, 20)

# %%
fechas
# Out:
#           fecha
# 0    11/07/2023
# 1    10/07/2023
# 2    09/07/2023
# 3    08/07/2023
# 4    07/07/2023
# ..          ...
# 511  05/01/2022
# 512  04/01/2022
# 513  03/01/2022
# 514  02/01/2022
# 515  01/01/2022
#
# [516 rows x 1 columns]

# %%
datos[0,19]
plt.figure(dpi=200)
avgs=[]
max_n=50
for i in range(1,max_n):
    ventas_avg=moving_average(datos[:,0],i)
    plt.plot(ventas_avg,color=(i/max_n, 0.4, 0.6, i/max_n))
    
plt.ylabel("media movil de ventas (pesos)")
plt.xlabel("Tiempo (dias)")
plt.show()
